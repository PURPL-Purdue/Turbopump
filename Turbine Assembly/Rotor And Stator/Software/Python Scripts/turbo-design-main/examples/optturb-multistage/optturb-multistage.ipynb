# %% [markdown]
# # OptTurb-Multistage
#
# Is based on a optimization campaign to design a turbine for Purdue AeroThermal Experimental Lab. It is based on a 1D meanline code; however, the full radial equilibrium equations are solved.
#
# The lab consists of storage of high pressure air at 138 bar paired to a heater allowing temperatures to reach 1090K. This is the exhausted to either athmosphere or a vacuum tank.
#
# A meanline code was used to design an optimal velocity triangle for a turbine given the range of operating conditions of the facility.
#
# In this example, we evalulate a multi-stage turbine. It's a similar design to the single stage example with an added stage (stator-rotor).
#
# The meanline spreadsheet was modified to take into account the extra stage.
# [Design Spreadsheet](https://github.com/nasa/turbo-design/blob/main/examples/optturb-multistage/multistage-fixed_pressure_loss2.xlsx)

# %%
# Installing the package
# !pip install turbo-design
# Out:
# 333.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: turbo-design in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (1.2.0)
# Requirement already satisfied: cantera in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (3.0.1)
# Requirement already satisfied: findiff in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (0.12.1)
# Requirement already satisfied: matplotlib in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (3.10.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (2.2.2)
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (2.2.3)
# Requirement already satisfied: plot3d in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (0.1.5)
# Requirement already satisfied: pyturbo-aero in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (1.0.25)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from turbo-design) (1.15.1)
# Requirement already satisfied: ruamel.yaml>=0.15.34 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from cantera->turbo-design) (0.18.10)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from findiff->turbo-design) (1.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from matplotlib->turbo-design) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pandas->turbo-design) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pandas->turbo-design) (2025.1)
# Requirement already satisfied: bz2file in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from plot3d->turbo-design) (0.98)
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from plot3d->turbo-design) (4.67.1)
# Requirement already satisfied: geomdl in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pyturbo-aero->turbo-design) (5.3.1)
# Requirement already satisfied: numpy-stl in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pyturbo-aero->turbo-design) (3.2.0)
# Requirement already satisfied: plotly in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from pyturbo-aero->turbo-design) (6.0.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->turbo-design) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from ruamel.yaml>=0.15.34->cantera->turbo-design) (0.2.12)
# Requirement already satisfied: python-utils>=3.4.5 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from numpy-stl->pyturbo-aero->turbo-design) (3.9.1)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from plotly->pyturbo-aero->turbo-design) (1.28.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from sympy->findiff->turbo-design) (1.3.0)
# Requirement already satisfied: typing_extensions>3.10.0.2 in /opt/homebrew/Caskroom/miniconda/base/envs/dev/lib/python3.12/site-packages (from python-utils>=3.4.5->numpy-stl->pyturbo-aero->turbo-design) (4.12.2)

# %%
from turbodesign import TurbineSpool, Inlet, RowType, BladeRow, Passage, Outlet, PassageType
from turbodesign.enums import MassflowConstraint
from turbodesign.coolant import Coolant
import numpy as np
from cantera import Solution

# %%
#%% Define the Passage
# Geometry from OptTurb
rmean = 0.389
H1 = 0.04
H2 = 1.159*H1
H3 = 1.317*H2
H4 = 1.1*H3
H5 = 1.1*H4
cax = (H1+H2+H3)/3

# Inlet, Stator Inlet, Stator Exit, Rotor Exit
rhub = [rmean-H1/2,rmean-H1/2,rmean-H2/2,rmean-H3/2,rmean-H4/2,rmean-H5/2]
rshroud = [rmean+H1/2,rmean+H1/2,rmean+H2/2,rmean+H3/2,rmean+H4/2,rmean+H5/2]
xhub = np.array([0, cax, 2*cax, 3*cax,4*cax,5*cax])
xshroud = np.array([0, cax, 2*cax, 3*cax,4*cax,5*cax])
axial_len = xhub[-1]-xhub[0]

passage = Passage(xhub,rhub,
                 xshroud,rshroud,
                 passageType=PassageType.Axial)

#%% Design Conditions
Design_RPM = 7500
massflow = 22    # kg/s, Initial guess
P0 = 1000000     # Pascal
T0 = 1300        # Kelvin

# Fluid
fluid = Solution('air.yaml')
fluid.TP = T0, P0 # Use pascal for cantera
print(f"Coefficient of Pressure [J/Kg] {fluid.cp:0.4f}")

#%% Defining the Inlet
inlet = Inlet(M=0.2,
                 P0=[P0],
                 T0=[T0],
                 beta=[0],
                 percent_radii=0.5,
                 location=cax/axial_len)
outlet = Outlet(P=P0/4.45,percent_radii=0.5,num_streamlines=3)

#%% Define Blade Rows
# Axial location is a percentage along the hub where row exit is defined
stator1 = BladeRow(row_type=RowType.Stator,location=2*cax/axial_len)
rotor1 = BladeRow(row_type=RowType.Rotor, location=3*cax/axial_len)
stator2 = BladeRow(row_type=RowType.Stator,location=4*cax/axial_len)
rotor2 = BladeRow(row_type=RowType.Rotor, location=5*cax/axial_len)

stator1.axial_chord = cax # Set an axial chord
rotor1.axial_chord = cax
stator2.axial_chord = cax
rotor2.axial_chord = cax

stator1.stage_id = 0; rotor1.stage_id = 0
stator2.stage_id = 1; rotor2.stage_id = 1

# Coolant Definition: Use Kelvin and Pascal. Coolant only needs P0, T0, massflow, and Cp
stator1.coolant = Coolant(T0=T0*0.555556, P0= P0 * 6894.76, massflow_percentage=0,Cp=fluid.cp) 
rotor1.coolant = Coolant(T0*0.555556, P0 * 6894.76,massflow_percentage=0,Cp=fluid.cp)
stator2.coolant = Coolant(T0=T0*0.555556, P0= P0 * 6894.76, massflow_percentage=0,Cp=fluid.cp) 
rotor2.coolant = Coolant(T0*0.555556, P0 * 6894.76,massflow_percentage=0,Cp=fluid.cp)


# Add in turning angles
stator1.beta2_metal = [72,72,72,72,72]        # Angle, hub,mean,tip
rotor1.beta2_metal = [-72,-72,-72,-72,-72]
stator2.beta2_metal = [70,70,70,70,70]
rotor2.beta2_metal = [-65,-65,-65,-65,-65]
# Out:
# Coefficient of Pressure [J/Kg] 1186.4871

# %% [markdown]
# Turbine example contains many different loss models. Two types of models currently supported are enthalpy based and pressure loss based. Users can write their own loss models, see source code for more information.

# %%
from turbodesign.loss.turbine import FixedPressureLoss

# These are all guessed values
stator1.loss_model = FixedPressureLoss(0.15)
rotor1.loss_model = FixedPressureLoss(0.18)
stator2.loss_model = FixedPressureLoss(0.15)
rotor2.loss_model = FixedPressureLoss(0.18)

# %%
spool = TurbineSpool(passage=passage,
            rpm=Design_RPM, 
            num_streamlines=5, 
            massflow=massflow, 
            fluid=fluid,
            rows=[inlet,stator1,rotor1,stator2,rotor2,outlet])
spool.massflow_constraint = MassflowConstraint.BalanceMassFlow # Fixes the exit angle and changes degree of reaction
# spool.plot_geometry()
spool.solve() # This also initializes streamlines
spool.export_properties("optturb.json")
spool.plot()
spool.plot_velocity_triangles()
# Out:
# Find average P in between stages
# [0.505 0.505 0.505]
# high massflow deviation detected
# [0.506 0.505 0.505]
# high massflow deviation detected
# [0.505 0.506 0.505]
# high massflow deviation detected
# [0.505 0.505 0.506]
# high massflow deviation detected
# [0.95 0.95 0.95]
# high massflow deviation detected
# [0.60330781 0.60330781 0.60330781]
# high massflow deviation detected
# [0.60430781 0.60330781 0.60330781]
# high massflow deviation detected
# [0.60330781 0.60430781 0.60330781]
# high massflow deviation detected
# [0.60330781 0.60330781 0.60430781]
# high massflow deviation detected
# [0.95 0.95 0.06]
# high massflow deviation detected
# [0.67969042 0.67969042 0.48360719]
# high massflow deviation detected
# [0.63806483 0.63806483 0.54883942]
# high massflow deviation detected
# [0.63906483 0.63806483 0.54883942]
# high massflow deviation detected
# [0.63806483 0.63906483 0.54883942]
# high massflow deviation detected
# [0.63806483 0.63806483 0.54983942]
# high massflow deviation detected
# [0.95       0.24768856 0.07922367]
# high massflow deviation detected
# [0.71168687 0.54592935 0.43800207]
# high massflow deviation detected
# [0.66828099 0.60025034 0.50334926]
# high massflow deviation detected
# [0.66928099 0.60025034 0.50334926]
# high massflow deviation detected
# [0.66828099 0.60125034 0.50334926]
# high massflow deviation detected
# [0.66828099 0.60025034 0.50434926]
# high massflow deviation detected
# [0.5494405  0.59045148 0.06      ]
# high massflow deviation detected
# [0.63367356 0.59739683 0.37424193]
# high massflow deviation detected
# [0.65277823 0.59897208 0.4455143 ]
# [0.65377823 0.59897208 0.4455143 ]
# [0.65277823 0.59997208 0.4455143 ]
# [0.65277823 0.59897208 0.4465143 ]
# [0.34217577 0.32796177 0.60684774]
# high massflow deviation detected
# [0.57128439 0.52786617 0.48784391]
# high massflow deviation detected
# [0.63296331 0.58168294 0.45580658]
# [0.64624047 0.59326768 0.44891014]
# [0.64724047 0.59326768 0.44891014]
# [0.64624047 0.59426768 0.44891014]
# [0.64624047 0.59326768 0.44991014]
# [0.62048572 0.62493267 0.46817713]
# high massflow deviation detected
# [0.63842423 0.6028776  0.45475743]
# [0.63942423 0.6028776  0.45475743]
# [0.63842423 0.6038776  0.45475743]
# [0.63842423 0.6028776  0.45575743]
# [0.64570019 0.59576831 0.49469559]
# [0.6405763  0.60077482 0.46657029]
# [0.6415763  0.60077482 0.46657029]
# [0.6405763  0.60177482 0.46657029]
# [0.6405763  0.60077482 0.46757029]
# [0.64834911 0.6011856  0.46123055]
# [0.64406353 0.60095912 0.46417464]
# [0.64506353 0.60095912 0.46417464]
# [0.64406353 0.60195912 0.46417464]
# [0.64406353 0.60095912 0.46517464]
# [0.64580399 0.59835213 0.45154024]
# [0.64457961 0.60018611 0.46042836]
# [0.64557961 0.60018611 0.46042836]
# [0.64457961 0.60118611 0.46042836]
# [0.64457961 0.60018611 0.46142836]
# [0.64203155 0.60204045 0.45938643]
# [0.64365342 0.60086014 0.46004963]
# [0.64465342 0.60086014 0.46004963]
# [0.64365342 0.60186014 0.46004963]
# [0.64365342 0.60086014 0.46104963]
# [0.63659363 0.59853789 0.46624012]
# [0.64203276 0.60032704 0.46147073]
# [0.64323192 0.60072149 0.46041923]
# [0.64350318 0.60081072 0.46018137]
# [0.64358499 0.60083763 0.46010963]
# [0.64361888 0.60084877 0.46007992]
# [0.64363515 0.60085413 0.46006565]
# [0.64364354 0.60085688 0.4600583 ]
# [0.64364801 0.60085835 0.46005438]
# [0.64365044 0.60085915 0.46005225]
# [0.64365177 0.60085959 0.46005108]
# [0.64465177 0.60085959 0.46005108]
# [0.64365177 0.60185959 0.46005108]
# [0.64365177 0.60085959 0.46105108]
# [0.64306253 0.6012039  0.46082939]
# [0.64339151 0.60101167 0.46039485]
# [0.64439151 0.60101167 0.46039485]
# [0.64339151 0.60201167 0.46039485]
# [0.64339151 0.60101167 0.46139485]
# [0.64293662 0.60010452 0.46069111]
# [0.64331151 0.60085213 0.46044695]
# [0.6433744  0.60097756 0.46040599]
# [0.64338752 0.60100373 0.46039745]
# [0.64339056 0.60100978 0.46039547]
# [0.64339128 0.60101122 0.460395  ]
# [0.64339145 0.60101156 0.46039489]
# [0.64339149 0.60101165 0.46039486]
# [0.6433915  0.60101166 0.46039485]
# [0.6433915  0.60101167 0.46039485]
# [0.6433915  0.60101167 0.46039485]
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.02063707375541646
#             Iterations: 13
#             Function evaluations: 89
#             Gradient evaluations: 13
# Adjusting Streamlines to balance massflow Row: 0
# Adjusting Streamlines to balance massflow Row: 1
# Adjusting Streamlines to balance massflow Row: 2
# Adjusting Streamlines to balance massflow Row: 3
# Adjusting Streamlines to balance massflow Row: 4
# [0.6433915  0.60101167 0.46039485]
# high massflow deviation detected
# Adjusting Streamlines to balance massflow Row: 0
# Adjusting Streamlines to balance massflow Row: 1
# Adjusting Streamlines to balance massflow Row: 2
# Adjusting Streamlines to balance massflow Row: 3
# Adjusting Streamlines to balance massflow Row: 4
# [0.6433915  0.60101167 0.46039485]
# high massflow deviation detected
# high massflow deviation detected
# Massflow convergenced error:7.9582417420956935
